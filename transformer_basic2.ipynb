# %%
# !pip install -U pip transformers
# Out:
# Requirement already satisfied: pip in /usr/local/lib/python3.12/dist-packages (24.1.2)
# Collecting pip
#   Downloading pip-25.2-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (4.56.2)
# Collecting transformers
#   Downloading transformers-4.57.0-py3-none-any.whl.metadata (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.4/41.4 kB 2.4 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers) (3.19.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.35.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.6.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.1.10)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2025.8.3)
# Downloading pip-25.2-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 34.8 MB/s eta 0:00:00
# Downloading transformers-4.57.0-py3-none-any.whl (12.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 84.8 MB/s eta 0:00:00
# Installing collected packages: pip, transformers
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.56.2
#     Uninstalling transformers-4.56.2:
#       Successfully uninstalled transformers-4.56.2
# Successfully installed pip-25.2 transformers-4.57.0

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM, pipeline

# %%
checkpoint = 'facebook/nllb-200-distilled-600M'
tokenizer = AutoTokenizer.from_pretrained(checkpoint)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/564 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/4.85M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.3M [00:00<?, ?B/s]
# special_tokens_map.json: 0.00B [00:00, ?B/s]

# %%
print(f"{len(tokenizer.vocab)}\n")

tokenizer.vocab
# Out:
# 256204
# {'▁پرسی': 44239,
#  '▁läks': 106944,
#  '▁not': 2294,
#  '▁labis': 201614,
#  '▁саты': 163671,
#  'seblief': 202918,
#  '▁puntu': 64222,
#  'డీ': 102542,
#  'erer': 8172,
#  '▁је': 1363,
#  '▁אפשרי': 232650,
#  'czę': 42194,
#  'གནངམ་': 130791,
#  'dı': 6361,
#  '▁zokugcina': 232184,
#  'ላለ': 35680,
#  '▁सब्': 120545,
#  '▁조작': 219008,
#  '▁завр': 38167,
#  'テゴ': 182782,
#  'ումբ': 164432,
#  '▁stim': 33983,
#  '▁महत्त्वपूर्ण': 137653,
#  '▁strike': 191310,
#  '▁amd': 77929,
#  '▁آگاه': 63017,
#  'עריק': 192760,
#  '▁verwa': 106274,
#  '▁екен': 33622,
#  'het': 1116,
#  '▁Andiamo': 236275,
#  '▁kha': 10211,
#  'impini': 214109,
#  '▁Európy': 210837,
#  '▁endhawini': 91805,
#  'لاردا': 61909,
#  '▁bimaze': 244366,
#  '▁սկսել': 197561,
#  'ಂಗ': 25371,
#  '▁baix': 75596,
#  '販': 251629,
#  'سیم': 52588,
#  '떳': 255853,
#  'gola': 149990,
#  '▁igbe': 124370,
#  '▁συμβ': 39665,
#  '▁رکن': 236358,
#  '▁Neki': 157121,
#  '▁niran': 181119,
#  '◆': 252105,
#  '▁lapsia': 245110,
#  '▁imyaka': 30124,
#  '▁gukorwa': 237315,
#  '▁wetu': 18131,
#  'UEL': 244238,
#  'ઠા': 152242,
#  'られます': 42277,
#  '▁dipaké': 160965,
#  '▁Jumala': 51597,
#  '三十': 248007,
#  'ලට': 34394,
#  'торо': 26423,
#  'સ્તી': 180090,
#  '▁verð': 91535,
#  '▁теперь': 78312,
#  '▁kĩĩroho': 175749,
#  'ၢ': 249277,
#  '▁jwalo': 169863,
#  'anire': 223768,
#  'èma': 200476,
#  '▁алко': 124865,
#  '▁ƙari': 162273,
#  '▁cyflwyno': 198730,
#  '▁Orlando': 203894,
#  '▁Luis': 83352,
#  '▁нивното': 200924,
#  '▁Instituto': 201538,
#  '▁이기': 125987,
#  '▁فراهم': 53052,
#  '▁자원': 139967,
#  '▁ಮನಸ್ಸ': 154688,
#  '行': 249062,
#  'araki': 125719,
#  'တေႃႇ': 102515,
#  '▁iñi': 194723,
#  '▁Sayang': 184635,
#  '▁다섯': 75512,
#  'тивност': 245273,
#  'ਧਾਨ': 59469,
#  '▁숭': 109942,
#  '▁पुग': 185535,
#  '▁nawng': 112334,
#  '▁Kry': 89453,
#  'wereka': 166639,
#  '▁зве': 89420,
#  '▁মালিক': 185370,
#  '设备': 193298,
#  'rsatish': 196255,
#  '▁پاری': 155895,
#  '▁kunayman': 176708,
#  '▁undersøg': 65446,
#  '▁πει': 72769,
#  '▁당신과': 89228,
#  'shit': 209720,
#  '▁carne': 68446,
#  '▁slož': 166698,
#  '▁connection': 137009,
#  'mā': 32528,
#  'adde': 11126,
#  '▁Επιτροπή': 53577,
#  '▁Hamma': 214700,
#  '▁بدەین': 245640,
#  '▁չպետք': 216107,
#  '▁division': 167460,
#  'дегі': 43341,
#  'णः': 138477,
#  '▁carga': 92882,
#  '▁तरुण': 220533,
#  '▁bono': 151365,
#  '▁Daugav': 159920,
#  '▁سول': 74490,
#  'vać': 149831,
#  '▁Beta': 108711,
#  'wiza': 43391,
#  '▁деректер': 168958,
#  'équ': 63888,
#  '▁många': 66035,
#  '▁Nayajj': 226059,
#  'τάει': 230736,
#  '▁Kuti': 25475,
#  '▁ئور': 41946,
#  '▁Tasol': 25676,
#  '▁резул': 36951,
#  '▁دوغرودان': 222336,
#  'iloba': 77441,
#  'vēro': 232405,
#  '▁univers': 11111,
#  '▁státu': 226494,
#  'рей': 47794,
#  '▁muele': 234212,
#  '▁leh': 4531,
#  'éu': 34030,
#  'lingkod': 192040,
#  '▁mahirap': 129295,
#  'imeli': 221258,
#  '▁သူ': 5859,
#  '▁tuon': 113431,
#  '▁kemana': 108181,
#  'ɣnɩ': 62210,
#  'lhes': 155613,
#  '▁әл': 32372,
#  'banan': 164441,
#  '▁خوانه': 158657,
#  'ଣ୍ଡିଆ': 189947,
#  '▁ბოლოს': 180829,
#  'tni': 132881,
#  '▁utilis': 62972,
#  'ostes': 168753,
#  '▁mpampi': 74593,
#  'dakı': 147068,
#  '▁Yrit': 113874,
#  '▁Gad': 59794,
#  '▁drodze': 205926,
#  '▁altes': 245807,
#  '▁سروس': 137105,
#  'larından': 46705,
#  '▁xəstə': 189869,
#  '▁სპ': 120500,
#  'kommer': 158156,
#  '▁5,5': 245750,
#  '▁2:16)': 220218,
#  '▁estaux': 105760,
#  'fini': 33792,
#  '▁izinkinga': 194268,
#  '▁Bibidia': 14713,
#  'Pay': 134292,
#  '▁Philippines': 80780,
#  '▁север': 100726,
#  'okoliv': 174551,
#  '▁Tec': 150344,
#  'ನೈ': 228894,
#  '▁aʋawɔ': 238798,
#  'гәр': 15446,
#  '▁વિદેશી': 241952,
#  'geten': 190793,
#  '▁diari': 242811,
#  'ovenim': 61527,
#  'を説明': 211032,
#  '▁ligg': 65163,
#  '▁ఇదే': 111568,
#  'cak': 6249,
#  'ಬು': 217734,
#  '直ちに': 231552,
#  '▁नियन्त्र': 195787,
#  '▁þessum': 63550,
#  '▁èdè': 67963,
#  'lizmus': 226352,
#  '▁September': 32684,
#  '▁vuravura': 33513,
#  '▁ffrind': 102421,
#  'wiyaɣ': 98352,
#  '▁mechani': 125534,
#  '็ค': 196943,
#  '▁طور': 6915,
#  '▁priložnost': 180576,
#  '▁ମ': 1750,
#  'તંત્ર': 110029,
#  '▁viranoma': 91590,
#  '▁akug': 168688,
#  '▁azonban': 58036,
#  'krar': 103165,
#  '▁marika': 152151,
#  '▁yépp': 140644,
#  'రి': 2034,
#  'ਜਾ': 35001,
#  '▁hinnen': 175028,
#  '▁pietiekami': 154240,
#  'akatulong': 142190,
#  '▁యువ': 141373,
#  '▁छू': 29524,
#  '▁chuyến': 77070,
#  '▁αφού': 201723,
#  '▁Donn': 217012,
#  '▁તેટ': 200265,
#  'նես': 85561,
#  'जाद': 65677,
#  '▁femme': 39435,
#  '▁تقول': 100239,
#  '▁사이에서': 135947,
#  '▁상황을': 109213,
#  'סא': 206214,
#  'ねばならない': 135239,
#  '▁օգտագործում': 198835,
#  '▁guts': 142221,
#  '▁उहे': 200499,
#  '▁ಸಮಯದ': 233174,
#  '▁영적': 100415,
#  '時点で': 86594,
#  '▁ضبط': 195943,
#  '▁şöhrat': 102449,
#  '▁vadītā': 60745,
#  'יו': 35542,
#  '▁schrei': 217225,
#  '▁shek': 13069,
#  '▁गाव': 206132,
#  '▁ժամանակը': 241263,
#  'সাম': 242718,
#  '▁léte': 106420,
#  'ulana': 90714,
#  '▁마음의': 178087,
#  '▁איפה': 92950,
#  '▁varo': 117168,
#  'ituta': 180408,
#  'ቿ': 254353,
#  '▁संरचना': 107418,
#  '▁अचानक': 109227,
#  '▁promised': 199203,
#  'mers': 87482,
#  '▁kʋñ': 137272,
#  '▁격': 69361,
#  '▁Belarus': 196809,
#  '▁တစ်ဦး': 164935,
#  '▁ruhaniya': 179857,
#  '▁pojma': 158815,
#  '▁berib': 176395,
#  '▁mladi': 108390,
#  '▁အဘယ်': 49415,
#  'zar': 3841,
#  '▁സ്ഥ': 36586,
#  '▁ফুটবল': 202647,
#  '▁እስኪ': 150002,
#  'стар': 14755,
#  '্যের': 177996,
#  '▁privac': 154227,
#  '▁mérték': 107707,
#  '▁zreteľom': 240726,
#  '▁sumang': 216504,
#  'mom': 114082,
#  'ۈب': 50514,
#  '▁handap': 122463,
#  '▁tšwela': 73531,
#  '▁sugu': 90479,
#  '▁گذشت': 140703,
#  '่นอน': 78900,
#  '▁imet': 127668,
#  '▁اولدولار': 246466,
#  '▁nkarhi': 12677,
#  'vorschriften': 151406,
#  '▁abay': 41559,
#  '▁tax': 16575,
#  '▁бомбар': 228391,
#  'రుకు': 78899,
#  'ものだった': 120852,
#  '▁feu': 62142,
#  '▁unitat': 233712,
#  '▁beaga': 179371,
#  '▁құқықтары': 244054,
#  'bọ': 19402,
#  '▁kuɗi': 115602,
#  '▁بوی': 146056,
#  '協': 250836,
#  'ologists': 245295,
#  'gwọ': 58318,
#  'дници': 107620,
#  '▁спрове': 125797,
#  'ugcina': 68344,
#  'સ્ક': 73975,
#  '▁magka': 101181,
#  'ਬਾਰ': 113071,
#  '▁zitandukanye': 233096,
#  '▁عليكم': 247150,
#  '▁velič': 153752,
#  '▁mku': 71872,
#  '▁фер': 79691,
#  '▁उहइ': 42694,
#  '▁今後': 154177,
#  'krát': 109809,
#  'tina': 18595,
#  '▁natrag': 200197,
#  '▁29-': 167491,
#  '▁લાઇ': 205079,
#  '▁بىزنى': 114707,
#  '▁pae': 65668,
#  '▁Duncan': 198588,
#  '▁gwm': 183696,
#  '▁الات': 155387,
#  '▁thuig': 221426,
#  'と言っている': 149738,
#  '▁कौनो': 137490,
#  'なくてはならない': 137311,
#  '▁čeprav': 161621,
#  'ដើម្បី': 65272,
#  'рив': 198416,
#  '▁эмеспи': 179749,
#  '▁дево': 183513,
#  '▁ukumkani': 230180,
#  '▁민감': 190772,
#  '▁ndiy': 239465,
#  '▁Έχεις': 114141,
#  'ଟିକୁ': 170959,
#  'fuk': 64822,
#  '▁kaya': 5457,
#  'ine': 392,
#  '▁esizayo': 216378,
#  '▁isiku': 63906,
#  '▁hasil': 23108,
#  '▁Minuten': 171349,
#  '▁исемен': 68512,
#  '▁VIH': 122488,
#  'ീപ': 130862,
#  '気分': 132480,
#  '▁bumoe': 101030,
#  '▁mil': 1962,
#  'lish': 12618,
#  'मुला': 211980,
#  'کم': 32280,
#  'იტ': 79963,
#  '▁શરીર': 191041,
#  '▁사람들을': 33973,
#  '▁ആത്മ': 172508,
#  '▁naragsak': 237183,
#  'ስዕብ': 172670,
#  '▁চাউ': 211453,
#  '▁оларды': 65745,
#  '▁Ийм': 91077,
#  'eldi': 187396,
#  '▁monato': 246604,
#  'wetso': 101649,
#  '▁یکه': 245198,
#  '▁kadaghanan': 150593,
#  'bats': 135480,
#  '▁esia': 34767,
#  'jụ': 52407,
#  '▁werking': 180566,
#  '▁પાંચ': 109857,
#  '▁Bugungi': 213450,
#  '▁mëny': 30792,
#  '▁दत्त': 223494,
#  '▁bengatla': 121326,
#  '▁soruş': 98195,
#  '▁ब्रिटिश': 135968,
#  '▁દુઃખ': 240298,
#  '▁ourselves': 127191,
#  '▁ঘ': 8354,
#  '▁journal': 85575,
#  '▁nejsou': 136898,
#  '▁ముఖ్యంగా': 158016,
#  'sụ': 161571,
#  '▁користат': 102005,
#  '▁siat': 85568,
#  '▁φωτογραφ': 183839,
#  '▁segun': 128110,
#  '▁týždeň': 181671,
#  '▁mesihçileriň': 188658,
#  'zah': 53729,
#  '▁Cando': 73452,
#  '▁кроме': 160740,
#  '▁tja': 220326,
#  'amahusay': 115927,
#  '志': 251751,
#  'elaa': 111895,
#  '▁makalada': 183836,
#  '▁tʋʋmã': 193591,
#  '▁laser': 68958,
#  'લાય': 191983,
#  '▁alina': 61030,
#  '▁orait': 37857,
#  '▁jiwat': 104260,
#  '▁sesama': 233887,
#  'fort': 23222,
#  '▁വാ': 27871,
#  '▁Punapike': 195897,
#  '▁kolonga': 215864,
#  '▁رکھا': 90482,
#  'lader': 239633,
#  '▁plane': 42206,
#  'andzela': 233369,
#  '▁xjenti': 176024,
#  '▁քննարկ': 164317,
#  '▁wantaim': 19948,
#  '▁spom': 78614,
#  '降示': 97566,
#  '▁ര': 8042,
#  '▁কৈছিল': 150023,
#  'oben': 124730,
#  'ħdu': 51047,
#  '▁Us': 11897,
#  '▁ወራት': 244110,
#  'ئلي': 145445,
#  '▁чемпи': 124242,
#  'vju': 177986,
#  '▁odzi': 162864,
#  '▁neznamená': 247580,
#  '▁vojn': 144144,
#  '▁сөн': 182999,
#  '▁완벽하게': 152013,
#  '▁sibi': 135404,
#  '▁satelit': 126157,
#  '▁Θεός': 167014,
#  '▁तभी': 168021,
#  '▁seulamat': 211937,
#  'bihiin': 237109,
#  'ஹ்': 37401,
#  'xer': 51090,
#  'ચ': 249201,
#  'ugamba': 112592,
#  '▁julle': 22965,
#  '▁болохгүй': 112999,
#  'cause': 13023,
#  '▁مبارک': 201020,
#  'Meunyoe': 152421,
#  'wszy': 225341,
#  '▁yaya': 36062,
#  'æn': 12923,
#  '▁letlalo': 215316,
#  '▁mobaynida': 215881,
#  'ulungele': 112493,
#  '▁ಧರ್ಮ': 163588,
#  'ွၼ်ႇ': 154186,
#  'ennem': 17177,
#  '曠': 255078,
#  '▁nithe': 168117,
#  '▁Zotin': 244514,
#  '▁Psalme': 142911,
#  '▁forretnings': 99490,
#  '▁kadaku': 51934,
#  '▁それから': 69212,
#  'שיא': 98479,
#  '▁ikak': 82776,
#  'ন্দি': 109366,
#  '▁გრძ': 127825,
#  '▁که': 817,
#  'ระห': 103128,
#  '▁ફ્રે': 138955,
#  '▁häsiýet': 128354,
#  '▁jame': 177377,
#  '▁unah': 126535,
#  '▁Dankon': 227744,
#  '▁kär': 29770,
#  'ampu': 81627,
#  '暫': 253791,
#  '따': 249905,
#  'త్మక': 156166,
#  'ગ': 248962,
#  '▁ጤና': 217752,
#  'haro': 161725,
#  '▁spørsmål': 85171,
#  '▁اسڪول': 177667,
#  '▁ijila': 136328,
#  'ສະຫຼ': 171628,
#  'esni': 86523,
#  'کەر': 144352,
#  '▁hula': 129945,
#  '▁akhala': 158748,
#  '없는': 46725,
#  'umbana': 138176,
#  'ārangi': 136382,
#  '▁voj': 49148,
#  '▁диҳед': 154969,
#  'angwe': 212434,
#  'ค้น': 156005,
#  '▁परन्तु': 102342,
#  '▁છોડ': 173023,
#  '▁कक्षा': 113784,
#  '▁17,': 29850,
#  'aeb_Arab': 256005,
#  'olovelo': 188846,
#  '▁Rakyat': 158170,
#  'Olu': 224697,
#  '▁служба': 126012,
#  'ellisesti': 136073,
#  '▁dużo': 111902,
#  '▁ɔka': 76036,
#  '▁वचन': 76811,
#  'anipha': 77100,
#  '▁1,0': 202866,
#  '▁ndrysho': 164323,
#  '▁знате': 163603,
#  'ोजे': 102105,
#  '▁3:23,': 222140,
#  '3-15)': 200269,
#  '깐': 253129,
#  'んでも': 170177,
#  '▁ynë': 142089,
#  '▁visible': 145321,
#  'сування': 70347,
#  '▁5:3)': 122576,
#  '▁געווא': 64334,
#  '▁insol': 160087,
#  'ýt': 14390,
#  'fundzisa': 150980,
#  '▁ئال': 10199,
#  'ମାତ୍ର': 247286,
#  'க்கொள்': 241367,
#  '▁ప్రదర్శ': 132241,
#  '▁layanan': 32038,
#  '▁asigna': 211251,
#  'ვნ': 24748,
#  '▁akhirnya': 43799,
#  '▁정도의': 164042,
#  'вез': 114449,
#  '▁သီ': 153786,
#  'lelanga': 220564,
#  '▁Arizona': 114902,
#  '▁saoire': 210590,
#  'βολ': 113616,
#  '▁sửa': 101695,
#  '▁nazionale': 132477,
#  '▁कवन': 124271,
#  '▁pranešė': 190212,
#  '▁মানে': 62291,
#  '▁9:': 22509,
#  '▁toidu': 212170,
#  'diction': 159307,
#  '▁forbud': 130665,
#  '▁луч': 52533,
#  '▁اروپایی': 114976,
#  '▁кое': 40381,
#  '▁सा': 1511,
#  '▁형태의': 169060,
#  '▁piso': 163194,
#  '▁رگ': 156776,
#  '▁Moni': 123760,
#  'wɛnɩ': 73327,
#  '▁काळजी': 116016,
#  'ାତ୍': 240934,
#  '▁Parlament': 26522,
#  'prs_Arab': 256142,
#  '▁suž': 87166,
#  '▁Ruth': 66137,
#  '▁واقف': 172143,
#  '▁WTO': 135779,
#  'cines': 204820,
#  '▁vraiment': 44500,
#  '▁Или': 54760,
#  '▁nustat': 24714,
#  '▁तल': 134628,
#  '▁җирдә': 122376,
#  '▁לנק': 237382,
#  '▁robh': 26963,
#  '▁agbiag': 217353,
#  '▁নাগ': 148043,
#  '▁ඕනේ': 94658,
#  '▁поната': 194887,
#  '▁áireamh': 126833,
#  '▁হিসাবে': 83775,
#  '▁ду': 3206,
#  '▁बरं': 245383,
#  '▁දැන්': 27038,
#  '▁tlod': 228496,
#  '耀': 253085,
#  '▁taur': 144435,
#  'ەندە': 77874,
#  '▁באופן': 59509,
#  'အမြ': 128858,
#  '▁vapaa': 177838,
#  '▁ضعیف': 179364,
#  'pita': 32525,
#  '▁پول': 21978,
#  '▁shach': 211497,
#  '▁informe': 64868,
#  'Šta': 207870,
#  'Yeova': 235174,
#  'tung': 30593,
#  '▁సంగీ': 169413,
#  'itx': 210893,
#  '▁हासिल': 95549,
#  'สึก': 63565,
#  '▁स्वतःच्या': 237495,
#  'akta': 73621,
#  '▁yed': 63528,
#  '天经': 146165,
#  '▁tabaka': 164080,
#  'lägg': 110575,
#  'üncü': 185831,
#  '▁Molo': 243169,
#  '▁चीन': 44327,
#  '▁Hunt': 133302,
#  '▁Có': 19428,
#  'λα': 5906,
#  'šhaba': 35638,
#  'hiana': 114586,
#  'Ah': 81426,
#  '▁undersök': 111918,
#  '▁huta': 246167,
#  'လုပ်': 13311,
#  'zatu': 182596,
#  '▁domnule': 151105,
#  '▁៩': 224220,
#  'ች': 248945,
#  'ារបស់': 225835,
#  'hatha': 16569,
#  'amah': 17531,
#  '▁fattige': 227602,
#  '▁Επι': 30460,
#  'ikot': 167671,
#  'niausiai': 155722,
#  '▁ကြိုးစား': 149490,
#  '▁berkenaan': 130719,
#  '▁נוסף': 159288,
#  '▁heart': 40938,
#  'robe': 105515,
#  '▁બીજું': 195867,
#  '☆': 252866,
#  '▁biện': 110445,
#  '▁plok': 226015,
#  '▁않은': 25131,
#  '▁Hakika': 80123,
#  '▁संबंधित': 52202,
#  '▁훈련을': 246719,
#  '▁nupui': 164385,
#  'क्षण': 20495,
#  '▁ọzụzụ': 214130,
#  '▁끊임없이': 130800,
#  '▁Rumah': 94642,
#  '▁وایه': 123416,
#  '▁क्रेडिट': 163060,
#  'hinji': 33843,
#  'شىنى': 35225,
#  '▁gɔmeɖose': 236116,
#  'arakter': 60108,
#  'Dhe': 227952,
#  '▁тогава': 101050,
#  'គ្រប់គ្រ': 188037,
#  'াতা': 112079,
#  '▁Wi': 7351,
#  'On': 29270,
#  '▁ikoll': 110101,
#  'ว์': 121249,
#  'மா': 8961,
#  'jnu': 108563,
#  '▁dio': 21317,
#  '▁নিশ্চয়ই': 178951,
#  '▁teritorijā': 147555,
#  '▁kudziwa': 87036,
#  'lication': 95102,
#  '▁mabilis': 126549,
#  'మూ': 95132,
#  '▁akşam': 159294,
#  '▁شنبه': 197902,
#  'ანს': 53628,
#  '▁prepoved': 205300,
#  'tanda': 142552,
#  'фі': 3184,
#  '▁County': 77236,
#  '▁Бигӯ': 164782,
#  'ႆႉ': 11102,
#  '▁vývoj': 146504,
#  'ُّ': 4557,
#  '▁menyu': 174181,
#  '▁Diri': 77009,
#  'fadhali': 182329,
#  '▁ਸ਼੍ਰੀ': 138585,
#  '▁број': 33371,
#  '▁พอ': 214472,
#  '▁miks': 74938,
#  'née': 39379,
#  '▁త్వర': 229948,
#  '▁தமிழ்': 97638,
#  '▁fem': 9710,
#  'ラーの': 226151,
#  'ජා': 210619,
#  '▁løb': 152588,
#  '▁Leh': 33887,
#  '▁fanomezana': 190881,
#  '▁লি': 28190,
#  'ôd': 167310,
#  'гности': 128239,
#  '▁ongel': 61967,
#  '▁ragione': 95813,
#  '▁проис': 116706,
#  '▁pelanggan': 41662,
#  'ላማ': 59281,
#  'ಮೆಯ': 192863,
#  '▁tingnan': 198605,
#  '▁ཁོང་གིས་': 25103,
#  'voda': 91524,
#  '▁abdii': 130846,
#  '罪': 250265,
#  '▁AH': 181362,
#  '▁ಸಾಲ': 157505,
#  '▁איתו': 154670,
#  '▁tó': 2989,
#  '8-': 71741,
#  '▁ă': 37680,
#  '▁jiteubiet': 196718,
#  '▁جانور': 130097,
#  '▁যথে': 83659,
#  '▁conso': 52372,
#  '▁zavar': 82457,
#  '▁Tento': 64174,
#  '一直': 103948,
#  '▁פינ': 195258,
#  '▁lev': 15859,
#  '▁дотор': 98584,
#  '▁terceira': 233742,
#  'ძღვ': 199221,
#  '▁duam': 234667,
#  '▁politics': 161188,
#  'orable': 148539,
#  '▁መር': 59544,
#  '▁sredstva': 120230,
#  '▁amhlaidh': 230017,
#  '▁izdev': 77824,
#  '▁Dîyi': 169935,
#  '▁ibutang': 235593,
#  '放射線': 184504,
#  'acord': 89273,
#  'liament': 63019,
#  '▁complete': 88379,
#  'folio': 133299,
#  'akaiba': 160949,
#  '▁qilinishi': 222343,
#  '▁финансо': 86635,
#  '▁ಅಂತಿಮ': 135034,
#  '▁жәр': 135342,
#  '▁surpr': 101703,
#  '年の': 13203,
#  '੪': 255876,
#  'हाल': 91117,
#  '▁vaší': 218474,
#  '▁रास्ता': 128119,
#  '▁maroro': 164311,
#  'ғыш': 50588,
#  '12/': 179142,
#  '▁റഷ്യ': 223644,
#  '▁ගමන': 207906,
#  '▁metu': 21857,
#  '▁කෙනා': 216204,
#  'prost': 202982,
#  '▁hming': 91819,
#  '▁phi': 19892,
#  'wisaka': 246937,
#  '▁masisi': 169183,
#  'に焦点を': 201582,
#  '▁душе': 212978,
#  '精': 250975,
#  '▁kesan': 69967,
#  '▁כח': 149767,
#  '▁betaal': 119961,
#  '▁miles': 79194,
#  '▁soqoni': 141168,
#  '▁मानसिक': 110705,
#  '▁قوربانگاه': 112305,
#  '▁인상': 222814,
#  ';"': 123696,
#  'པ་ཡིན་': 40985,
#  'ස්ත': 175155,
#  '▁vreugde': 162389,
#  '▁የተሻለ': 128491,
#  '▁саҡы': 119197,
#  '▁pies': 48254,
#  '▁ରୂପେ': 231776,
#  '▁198': 3470,
#  '▁مرده': 177116,
#  '▁dumb': 197533,
#  '▁эв': 226887,
#  '▁kplii': 159018,
#  '颜': 255419,
#  '▁అం': 72234,
#  '▁łe': 127864,
#  'ਐੱਸ': 183760,
#  '▁ujuzi': 170566,
#  'joj': 26880,
#  '▁karano': 55778,
#  '▁ਹਾਈ': 213946,
#  '▁godkendt': 207472,
#  '▁pagam': 180033,
#  '▁asengelaki': 193525,
#  '▁ਸੁਰੱਖਿਆ': 125891,
#  '▁level': 29633,
#  'ಿಸಿದರೆ': 128159,
#  '▁distancia': 116649,
#  '▁même': 18754,
#  '▁সাক্ষ': 100540,
#  'གཙ': 47923,
#  '▁birine': 117076,
#  '▁anplwaye': 219262,
#  '▁teem': 164376,
#  'gamber': 207418,
#  '▁さ': 16184,
#  '▁boire': 97920,
#  '▁rust': 146433,
#  '▁incluíndo': 237659,
#  '話題': 111289,
#  'стим': 219448,
#  'par': 1591,
#  '▁ezit': 67188,
#  '▁အဘယ်သို့': 243282,
#  '▁tussen': 29538,
#  'Des': 129214,
#  '▁तिचा': 225692,
#  '▁bhliadhna': 154030,
#  '▁դեղ': 220656,
#  '▁którą': 144260,
#  '▁Landes': 197236,
#  '▁פארשט': 125785,
#  '▁ବିଷ': 41179,
#  '▁аль': 45049,
#  'થે': 9345,
#  'ometheo': 214133,
#  'istum': 134587,
#  'ئنئز': 30404,
#  '▁nguM': 189955,
#  '▁jirta': 212313,
#  'ẫ': 250192,
#  '▁사업을': 127870,
#  '丧': 254472,
#  '▁Daudi': 54793,
#  '▁instituições': 200704,
#  '▁nitaj': 232294,
#  '▁kwao': 129037,
#  '▁יפה': 144882,
#  '▁അല്ലാഹുവി': 96160,
#  '▁ئالما': 209644,
#  '▁oamenii': 95431,
#  'సులు': 149701,
#  '▁유혹': 140689,
#  '▁периште': 187059,
#  'үл': 7943,
#  'մի': 88258,
#  '▁Рӯ': 186027,
#  'ահան': 192436,
#  '▁роди': 78026,
#  'ទំនង': 186658,
#  '▁પ્લા': 141045,
#  'iejs': 71531,
#  '▁1958.': 226354,
#  '▁पित': 99345,
#  'ನೀ': 114546,
#  '▁pon': 6148,
#  '▁сега': 27712,
#  'ло': 376,
#  '▁každú': 222141,
#  '▁varten': 79207,
#  '▁ула': 130218,
#  '▁कहि': 41305,
#  'igil': 60488,
#  '▁सोना': 227266,
#  'elelo': 19080,
#  'ukhumba': 80214,
#  'ināta': 84061,
#  'laks': 28250,
#  '▁zobo': 171726,
#  '▁រហូត': 154601,
#  '▁אמרתי': 122626,
#  'engan': 1605,
#  '▁Blockchain': 168891,
#  '▁Eins': 41531,
#  '▁एकटा': 79431,
#  'ནུག': 11089,
#  '▁зүйл': 29797,
#  '▁उत्पादों': 146521,
#  'ክርስት': 245373,
#  '▁toprak': 211265,
#  '▁Yebo': 108170,
#  '▁анықтау': 131948,
#  '▁유지하고': 244145,
#  'CC': 22493,
#  'ציאות': 217924,
#  '汶': 255130,
#  'Quién': 140142,
#  'கிற': 10798,
#  'ering': 5334,
#  '▁boumeli': 93696,
#  '▁identidá': 57525,
#  '▁Mashahidi': 77986,
#  '▁алушы': 106500,
#  'ландыру': 67429,
#  '▁był': 32483,
#  '▁kbira': 123421,
#  '▁Artikel': 25917,
#  '▁odkaz': 231795,
#  'hombisa': 115738,
#  '▁འཚུབ་': 92858,
#  'ytes': 202584,
#  '罪を': 106007,
#  '▁почта': 205525,
#  '▁kĩrĩa': 100561,
#  '▁Dwi': 127028,
#  '▁Poţi': 155561,
#  '▁vaiaso': 123778,
#  '▁Kala': 21588,
#  '్రె': 98753,
#  '▁ịch': 42357,
#  'ଡ': 249393,
#  'ຊ່ວຍ': 95957,
#  '▁가만': 235981,
#  'જિન': 208126,
#  'Sy': 202952,
#  '▁साध': 76345,
#  'ylene': 226916,
#  '▁wise': 185564,
#  'laimint': 130942,
#  'ძი': 141070,
#  '▁naJehovha': 110495,
#  '▁것이었다': 94089,
#  'རྩིས་': 95448,
#  'ப்ப': 1721,
#  '▁ژن': 46529,
#  '▁सोने': 204833,
#  '▁maaliifi': 123388,
#  '▁gamle': 54544,
#  '▁불과': 97844,
#  '▁bansa': 21709,
#  'cijām': 115867,
#  '▁inspir': 31528,
#  '▁atake': 240311,
#  'seli': 161523,
#  '▁берілетін': 175585,
#  '▁mediante': 59492,
#  'డర్': 187963,
#  '▁ngumntu': 230684,
#  'umah': 8637,
#  '▁కంప': 81898,
#  '▁بېرىڭلار': 195900,
#  'แทน': 128130,
#  '▁Santos': 143087,
#  '▁ҡылған': 217532,
#  '▁âm': 55024,
#  '▁тота': 94315,
#  '▁შემი': 159008,
#  '▁31;': 174436,
#  'うえ': 179495,
#  'چئلر': 232065,
#  '▁යනවා': 118202,
#  '▁prelimin': 130717,
#  '▁leasa': 112099,
#  '▁ඕනෑ': 195263,
#  '▁Ester': 110821,
#  'ହା': 4703,
#  '▁sexy': 78753,
#  '▁دەڕ': 164978,
#  '▁shimcha': 137005,
#  'ເຫຼືອ': 165902,
#  'ནུ་': 210900,
#  '▁هفت': 70241,
#  '▁रहि': 53527,
#  '▁gizli': 163986,
#  '▁troi': 170554,
#  '▁Rem': 34600,
#  '▁mindent': 95729,
#  '▁disenyo': 239710,
#  '▁честь': 180542,
#  'ײַן': 88431,
#  '▁žal': 63638,
#  '大使館': 220649,
#  '▁jeszcze': 35843,
#  '▁tembiapo': 157823,
#  'を殺': 88192,
#  '▁ኣይነበረ': 194127,
#  '▁define': 119726,
#  '一致': 86062,
#  '▁eerder': 86809,
#  '▁choti': 123860,
#  '▁grootste': 78627,
#  '▁waabwe': 236809,
#  '▁សេ': 246298,
#  'tjet': 149232,
#  'ረው': 38795,
#  ...}

# %%
thai_char_min = 0x0E00
thai_char_max = 0x0E7F

thai_tokens = [
    token for token in tokenizer.vocab.keys()
    if any(thai_char_min <= ord(char) <= thai_char_max for char in token)
]

thai_token_count = len(thai_tokens)
sample_size = 20
thai_tokens_sample = thai_tokens[:sample_size]


print(f"{thai_token_count}\n")
for token in thai_tokens_sample:
  print(token)
# Out:
# 1712
#
# ▁ไร
# มั๊ย
# ของพระองค์
# ▁อย่าง
# ราม
# โช
# ณี
# ▁แค่
# ใกล้
# สุทธิ์
# ใหญ่
# ท
# กระทํา
# ▁บริ
# ั้ย
# อยู่ที่นี่
# ▁เค
# ซัก
# ▁เจ
# ชุม

# %%
import tensorflow as tf
import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots
import numpy as np
import math

# %%
sentence = 'Work hard, play harder'

# %%
cleaned_sentence = sentence.replace(',', '')
cleaned_sentence
# Out:
# 'Work hard play harder'

# %%
words = cleaned_sentence.split()
words
# Out:
# ['Work', 'hard', 'play', 'harder']

# %%
sorted_words = sorted(words)
sorted_words
# Out:
# ['Work', 'hard', 'harder', 'play']

# %%
dc = {word: index for index, word in enumerate(sorted_words)}
dc
# Out:
# {'Work': 0, 'hard': 1, 'harder': 2, 'play': 3}

# %%
sentence_int = tf.constant(
    [dc[s] for s in sentence.replace(',', '').split()],
    dtype=tf.int32
)

# %%
print(sentence)
print(sentence_int)
# Out:
# Work hard, play harder
# tf.Tensor([0 1 3 2], shape=(4,), dtype=int32)

# %%
# สร้าง embedding layer
tf.random.set_seed(123)
vocab_size = 50_000
embedding_dim = 2

embed = tf.keras.layers.Embedding(input_dim=vocab_size, output_dim=embedding_dim)

# %%
embedded_sentence = embed(sentence_int)

# %%
embedded_sentence
# Out:
# <tf.Tensor: shape=(4, 2), dtype=float32, numpy=
# array([[ 0.03768668,  0.02805283],
#        [-0.04673613, -0.02042915],
#        [ 0.03982434, -0.01036913],
#        [ 0.02676517,  0.03103485]], dtype=float32)>

# %%
tf.random.set_seed(123)
vocab_size = 50_000
embedding_dim = 2

dummy_input = tf.constant([0, 1, 2], dtype=tf.int32)

# Case 1 Default initializer (RandomUniform(-0.05, 0.05))
embed_default = tf.keras.layers.Embedding(input_dim=vocab_size, output_dim=embedding_dim)
_ = embed_default(dummy_input) # เรียกใช้งาน layer เพื่อสร้าง weights
weights_default = embed_default.get_weights()[0].flatten()
weights_default.shape
# Out:
# (100000,)

# %%
# Case 2 GlorotUniform initializer
tf.random.set_seed(123)
embed_glorot = tf.keras.layers.Embedding(
    input_dim=vocab_size,
    output_dim=embedding_dim,
    embeddings_initializer=tf.keras.initializers.GlorotUniform()
)
_ = embed_glorot(dummy_input) # เรียกใช้งาน layer เพื่อสร้าง weights
weights_glorot = embed_glorot.get_weights()[0].flatten()
weights_glorot.shape
# Out:
# (100000,)

# %%
fig = make_subplots(rows=1, cols=1)

fig.add_trace(go.Histogram(x=weights_default, nbinsx=50, name="Default Uniform [-0.05, 0.05]", opacity=0.6))
fig.add_trace(go.Histogram(x=weights_glorot, nbinsx=50, name="Glorot Uniform", opacity=0.6))

fig.update_layout(
    title_text='Embedding Layer Initialization Comparison',
    xaxis_title_text='Weight values',
    yaxis_title_text='Frequency',
    barmode='overlay',
    legend_orientation="h",
    legend_yanchor="bottom",
    legend_y=1.02,
    legend_xanchor="right",
    legend_x=1
)

fig.show()

print("Default initializer range ", weights_default.min(), weights_default.max())
print("Glorot initializer range ", weights_glorot.min(), weights_glorot.max())
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="1306b793-5a66-4d28-8b31-a92a0f21591c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1306b793-5a66-4d28-8b31-a92a0f21591c")) {                    Plotly.newPlot(                        "1306b793-5a66-4d28-8b31-a92a0f21591c",                        [{"name":"Default Uniform [-0.05, 0.05]","nbinsx":50,"opacity":0.6,"x":[-0.043358732,0.019223679,-0.04456147,-0.000044345856,-0.026640082,-0.048957635,0.0048808083,0.004721619,0.0053792708,-0.009581577,-0.048671532,-0.006418716,-0.019489361,0.00089082867,-0.020996487,0.042037155,-0.04889014,-0.028390288,0.04761635,0.026142787,0.038828943,0.04203758,0.017620768,-0.04980445,0.004746355,-0.018442594,-0.02903818,0.020980705,-0.041450012,-0.03470874,0.045909707,-0.035750378,0.025395777,-0.04603224,0.018685315,-0.036347616,0.043160345,-0.04973476,0.045151565,-0.00534619,-0.033159185,-0.03684343,0.008364629,0.037570503,-0.04175041,0.026256833,-0.028839732,-0.021868194,-0.0055706277,0.0061361417,0.038589265,0.026651237,0.04719201,-0.0417899,-0.041872717,0.049684707,-0.017413579,0.03912996,-0.026142884,0.028955687,0.0035563223,-0.03188014,0.0030627362,-0.04606402,0.0283877,-0.03193121,-0.009734772,-0.0014394894,-0.0020877346,-0.042541265,0.04661076,-0.02523358,-0.032067254,0.016515914,-0.028523494,-0.035552345,0.004907239,-0.015254986,-0.034686767,0.0016140118,-0.042544734,0.007973254,-0.014132928,0.041009974,-0.043683387,-0.014287613,-0.009500921,0.03234713,0.006165456,0.011174571,0.03277752,0.035741713,-0.005830586,-0.007468831,0.024270963,-0.018213678,0.04540867,0.022502769,0.016231429,-0.030750586,0.006613709,0.037386548,0.015643347,-0.01785642,0.012672495,0.0017442331,0.012277365,-0.0092667565,0.029297125,0.02619246,-0.048627127,0.026870634,-0.024266398,-0.04311421,0.011345733,-0.010778714,-0.032710567,0.00721569,-0.03559829,0.010242034,0.01971208,-0.013635527,0.013680827,-0.0065755025,-0.007995822,-0.044725277,-0.016313113,0.0041108616,0.02618866,-0.02733897,0.04592297,0.042286802,-0.03292252,-0.027387572,0.03260703,-0.018387057,-0.027265072,0.02963673,-0.03322418,0.009331692,0.049288344,0.035127852,0.029001486,-0.02104553,0.040478814,0.021296058,0.008372463,-0.031947363,-0.041557085,-0.046046782,0.04419894,-0.016932439,0.04466257,-0.046441864,0.04181992,-0.007596493,-0.024652397,-0.0025585406,-0.0011476167,-0.020521045,-0.037692584,0.0057094693,0.049669515,-0.03355483,0.03377564,0.0027697198,0.0013001338,0.01303431,-0.010007776,-0.04979843,0.0014448538,0.0390183,0.01548605,-0.001593113,0.037375282,-0.03957349,0.029700268,0.010696638,0.012129404,-0.048265338,-0.038721897,-0.043707896,-0.031318463,-0.0012261495,0.037162494,-0.010734331,-0.028572047,-0.027802492,-0.01812315,0.04011972,-0.026255285,0.020865683,-0.0133518465,-0.0052981153,-0.0007607825,-0.035096694,0.018315587,-0.004788302,-0.048205722,-0.007642366,-0.045030545,0.0081725605,-0.012778364,0.014874373,0.009762883,0.04626297,-0.008433081,-0.0150225535,0.037517395,-0.021966113,0.033055577,0.040709067,0.0052321665,-0.015286349,0.010906257,0.008923579,0.03021003,-0.049424898,-0.010367475,0.0110134855,0.022591662,0.04175845,-0.027929783,0.025960717,0.04822438,-0.03353043,0.0051358826,-0.023272062,0.043953884,-0.026102042,-0.03687489,0.04848111,0.021291051,0.036302354,-0.017036438,0.034958947,-0.008328486,-0.018417098,-0.020755673,-0.046601724,0.044944968,0.018575218,0.020409655,-0.007119786,0.048284147,0.033601735,0.00050321966,-0.032400787,-0.03689605,-0.0074306354,0.0049120076,0.000108122826,-0.014915872,-0.031667806,0.02646656,0.01582304,-0.017949175,-0.038249172,-0.017274212,0.012979124,-0.002296351,0.04520234,-0.0017681345,0.044903446,0.0054347143,-0.0069458373,-0.0020892993,-0.004558526,-0.017782401,-0.003845431,0.02 ...
# Default initializer range  -0.04999875 0.049999107
# Glorot initializer range  -0.0109537775 0.010953979

# %%
def glorot_uniform_limits(fan_in, fan_out):
    limit = math.sqrt(6.0 / (fan_in + fan_out))
    a, b = -limit, limit
    return a, b

# ตัวอย่าง Embedding layer (vocab_size=50000, embedding_dim=2)
fan_in = 50000
fan_out = 2

a, b = glorot_uniform_limits(fan_in, fan_out)
print("Glorot Uniform a =", a)
print("Glorot Uniform b =", b)
# Out:
# Glorot Uniform a = -0.010954232067652772
# Glorot Uniform b = 0.010954232067652772

# %%
model = AutoModelForSeq2SeqLM.from_pretrained(checkpoint)
# Out:
# config.json:   0%|          | 0.00/846 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/2.46G [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.46G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/189 [00:00<?, ?B/s]

# %%
token_embedding_layer = model.model.encoder.embed_tokens
token_embedding_layer.weight.shape
# Out:
# torch.Size([256206, 1024])

# %%
long_sentence = "In the vast realm of natural language processing, understanding the nuances of how models handle sequential data is crucial. Positional encoding plays a vital role in providing this essential information to the model, allowing it to differentiate between words at different positions in a sentence, which is fundamental for tasks like translation, summarization, and text generation."

# %%
tokens = tokenizer(long_sentence, return_tensors="pt")

print(tokens['input_ids'][0])
# Out:
# tensor([256047,    717,    349,  14430,  12284, 248070,    452,  25307,  65445,
#         157278, 248079, 133930,    349,    713,  75831,    452,  11657, 141057,
#          47274, 116914, 124785,   6067,    248, 182071, 248075,  12013,  58409,
#          12025, 246156,   3054,    705,      9, 104781,  76065,    108, 174693,
#           3423, 140515,  18781,    202,    349,  14916, 248079,  82935,     87,
#            796,    202,  53054,    502,  25914,  51744,    230,  30158, 199073,
#            108,      9, 109267, 248079,   9089,    248,  75529,    351, 226047,
#           6399, 200356, 248079,   2493, 109207, 181953, 248079,    540,  35883,
#         120531, 248075,      2])

# %%
len(tokens['input_ids'][0])
# Out:
# 75

# %%
token_embedding_layer(tokens['input_ids'][0][0]).shape
# Out:
# torch.Size([1024])

# %%
token_embeddings = token_embedding_layer(tokens['input_ids'][0])

print("Token Embedding Matrix shape", token_embeddings.shape)
token_embeddings
# Out:
# Token Embedding Matrix shape torch.Size([75, 1024])
# tensor([[-5.0000e+00, -1.2725e+00, -9.3604e-01,  ..., -1.8297e+01,
#          -9.1328e+00, -1.0672e+01],
#         [ 2.6416e-01,  2.6831e-01,  2.0117e-01,  ...,  3.2715e+00,
#          -3.2402e+00,  3.1738e+00],
#         [ 4.3579e-01, -2.3352e-01,  2.6825e-02,  ...,  5.4648e+00,
#           2.7129e+00,  5.5430e+00],
#         ...,
#         [ 8.5859e+00, -4.5391e+00, -4.7314e-01,  ..., -7.9529e-02,
#           7.4844e+00, -7.5156e+00],
#         [-2.4863e+00, -2.7515e-01,  5.6114e-03,  ...,  1.0180e+01,
#          -7.2422e+00, -4.8047e+00],
#         [-7.8320e-01, -9.0527e-01, -9.4482e-01,  ...,  3.1078e+01,
#          -8.1494e-01, -8.7354e-01]], grad_fn=<MulBackward0>)

# %%
import plotly.express as px

token_embeddings_np = token_embeddings.detach().numpy()

fig = px.imshow(
    token_embeddings_np,
    color_continuous_scale="RdBu",
    labels=dict(x="Embedding Dimension", y="Token Index", color="Value"),
    title="Token Embedding Heatmap"
)

fig.update_xaxes(side="top")
fig.update_layout(height=500, width=900)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="a56f394b-1017-4205-8532-2d85912eede5" class="plotly-graph-div" style="height:500px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a56f394b-1017-4205-8532-2d85912eede5")) {                    Plotly.newPlot(                        "a56f394b-1017-4205-8532-2d85912eede5",                        [{"coloraxis":"coloraxis","name":"0","z":[[-5.0,-1.2724609,-0.93603516,-0.83203125,-2.8164062,-1.4824219,-1.4541016,-1.5322266,-2.0976562,-1.3632812,-1.3916016,-0.8466797,-0.40673828,-2.1171875,-2.9785156,-5.9257812,-3.2480469,-3.2265625,-5.4296875,-4.6445312,-4.6210938,-2.7578125,1.6699219,0.23669434,2.6699219,0.6894531,2.1640625,-1.4003906,-1.5332031,1.078125,0.27319336,-0.044677734,-4.484375,2.7148438,-0.82714844,-0.9248047,-1.4833984,1.5966797,0.3942871,2.7675781,-0.18151855,-1.4208984,1.4765625,-3.5234375,-1.9033203,-0.36523438,-3.0449219,-7.0078125,3.3378906,-2.4453125,-1.21875,0.6464844,-0.20788574,0.50927734,-0.35546875,2.6171875,-1.484375,-7.21875,-1.6210938,-4.1679688,-6.3476562,0.6245117,-0.8540039,-0.36621094,0.53759766,-4.03125,-1.4160156,-1.6035156,-0.20056152,-2.6367188,0.5800781,-4.2421875,-1.0517578,1.6572266,-3.7011719,-2.1425781,-2.3203125,-0.46142578,-3.1484375,-3.5039062,5.1484375,1.5410156,-2.4667969,1.8359375,-0.8930664,1.2636719,-2.5976562,1.8720703,-1.9160156,1.6894531,-0.9248047,-3.6503906,-2.6464844,3.9433594,-1.8027344,0.08276367,-2.3632812,-0.3720703,-1.2607422,-1.0986328,0.82666016,-2.9101562,-0.7949219,3.4023438,3.4804688,-5.0664062,1.2001953,-2.8222656,-0.0925293,-0.06573486,-4.15625,-0.24804688,-5.2421875,-5.2070312,-1.1210938,-2.1269531,-0.9296875,1.3291016,0.5756836,3.2910156,0.028930664,-3.2949219,-0.74902344,1.9746094,3.2324219,-2.9824219,-4.078125,2.9355469,-0.37890625,-6.0429688,-1.1982422,5.2929688,-0.9555664,-1.0087891,-2.4609375,-2.8320312,7.0390625,1.34375,6.0195312,-4.3007812,-0.33691406,1.3554688,1.9746094,0.88964844,-0.8432617,-1.1689453,2.0429688,-3.375,-2.2167969,-1.0732422,-6.8984375,5.59375,0.70751953,-2.4511719,1.0996094,2.953125,1.5742188,0.7495117,-4.53125,-2.7207031,2.3007812,0.19958496,1.5048828,-2.625,4.9140625,1.2363281,-1.4033203,-0.7739258,2.9023438,-1.9794922,0.5097656,-5.03125,4.3164062,-1.4628906,-3.6289062,7.9023438,-5.4101562,-0.79541016,1.2724609,-3.03125,-3.2617188,-0.7285156,9.453125,6.8710938,-0.78027344,0.8461914,-0.028656006,-1.4453125,-0.89697266,0.20361328,-5.5234375,-3.1992188,0.09460449,5.4921875,-2.9335938,5.6484375,0.92285156,2.1542969,-3.6738281,-2.5722656,-5.1953125,-4.4296875,6.0625,2.1171875,-0.19140625,2.3886719,-2.3144531,-1.4082031,1.1728516,9.0859375,-5.3789062,-0.14526367,-3.1972656,1.8076172,0.8041992,2.4199219,-0.009849548,-6.2070312,-1.6171875,-3.8027344,2.0898438,-2.5351562,0.86816406,0.17224121,-0.5800781,3.7070312,1.9980469,5.015625,-1.7001953,-0.2734375,-1.4921875,3.2675781,-1.4570312,-3.8964844,-1.7021484,-5.0351562,2.5410156,-4.4414062,-2.9394531,9.359375,-0.703125,-0.5439453,-11.515625,4.1367188,6.640625,2.7636719,-2.6054688,-0.5625,1.6259766,0.94140625,0.2746582,0.24401855,-5.3671875,4.6367188,-5.25,6.1484375,-5.5429688,-0.3149414,-2.1875,-2.0859375,-1.1806641,7.3671875,-0.17993164,-1.1494141,-15.9296875,-1.5449219,-3.7226562,-4.6484375,3.0507812,5.1835938,-2.4550781,3.71875,-0.9057617,8.40625,0.1361084,-4.65625,3.203125,0.28466797,-7.28125,-2.9941406,-5.0625,0.92578125,-12.6796875,-5.2929688,0.47802734,18.0625,-11.078125,3.34375,-3.3222656,0.3605957,-6.3164062,-17.1875,3.6796875,-4.4257812,-8.4375,-6.2578125,16.046875,-4.4570312,0.10467529,0.18127441,-4.0664062,-0.4375,1.3125,-1.5859375,-3.6503906,-5.1875,0.32910156,-3.6367188,-3.1835938,-1.5380859,-2.1601562,2.2910156,2.0507812,4.1367188,3.1503906,-0.33325195,-0.03668213,0.8671875,-2.8515625,-7.3359375,-2.9296875,-4.6015625,0.0 ...

# %%
d = embedded_sentence.shape[-1]
d
# Out:
# 2

# %%
d_q, d_k, d_v = 2, 2, 4

d_q, d_k, d_v
# Out:
# (2, 2, 4)

# %%
tf.random.set_seed(123)
W_query = tf.Variable(tf.random.uniform((d, d_q)), trainable=True)
W_key   = tf.Variable(tf.random.uniform((d, d_k)), trainable=True)
W_value = tf.Variable(tf.random.uniform((d, d_v)), trainable=True)

# %%
print(W_query.shape, W_key.shape, W_value.shape)
# Out:
# (2, 2) (2, 2) (2, 4)

# %%
W_query
# Out:
# <tf.Variable 'Variable:0' shape=(2, 2) dtype=float32, numpy=
# array([[0.12615311, 0.5727513 ],
#        [0.2993133 , 0.5461836 ]], dtype=float32)>

# %%
W_key
# Out:
# <tf.Variable 'Variable:0' shape=(2, 2) dtype=float32, numpy=
# array([[0.88968754, 0.12354946],
#        [0.7718717 , 0.6850728 ]], dtype=float32)>

# %%
W_value
# Out:
# <tf.Variable 'Variable:0' shape=(2, 4) dtype=float32, numpy=
# array([[0.48962688, 0.5857923 , 0.36451697, 0.6550509 ],
#        [0.9075084 , 0.37557673, 0.6882372 , 0.25384045]], dtype=float32)>

# %%
embedded_sentence
# Out:
# <tf.Tensor: shape=(4, 2), dtype=float32, numpy=
# array([[ 0.03768668,  0.02805283],
#        [-0.04673613, -0.02042915],
#        [ 0.03982434, -0.01036913],
#        [ 0.02676517,  0.03103485]], dtype=float32)>

# %%
queries = tf.matmul(embedded_sentence, W_query)
keys    = tf.matmul(embedded_sentence, W_key)
values  = tf.matmul(embedded_sentence, W_value)

# %%
print("Queries shape", queries.shape)
queries
# Out:
# Queries shape (4, 2)
# <tf.Tensor: shape=(4, 2), dtype=float32, numpy=
# array([[ 0.01315088,  0.03690709],
#        [-0.01201062, -0.03792625],
#        [ 0.00192035,  0.01714599],
#        [ 0.01266565,  0.03228052]], dtype=float32)>

# %%
print("Keys shape", keys.shape)
keys
# Out:
# Keys shape (4, 2)
# <tf.Tensor: shape=(4, 2), dtype=float32, numpy=
# array([[ 0.05518255,  0.0238744 ],
#        [-0.05734923, -0.01976968],
#        [ 0.02742758, -0.00218333],
#        [ 0.04776756,  0.02456796]], dtype=float32)>

# %%
print("Values shape", values.shape)
values
# Out:
# Values shape (4, 4)
# <tf.Tensor: shape=(4, 4), dtype=float32, numpy=
# array([[ 0.04391059,  0.03261256,  0.03304444,  0.03180763],
#        [-0.04142289, -0.03505038, -0.03109621, -0.03580029],
#        [ 0.01008899,  0.01943439,  0.00738022,  0.02345486],
#        [ 0.04126934,  0.0273348 ,  0.0311157 ,  0.02541045]],
#       dtype=float32)>

# %%
omega = tf.matmul(queries, keys, transpose_b=True)

print("Omega shape", omega.shape)
print("Omega (Unnormalized attention weights)")
print(omega)
# Out:
# Omega shape (4, 4)
# Omega (Unnormalized attention weights)
# tf.Tensor(
# [[ 1.6068339e-03 -1.4838341e-03  2.8011625e-04  1.5349172e-03]
#  [-1.5682434e-03  1.4385898e-03 -2.4661666e-04 -1.5054885e-03]
#  [ 5.1531987e-04 -4.4910100e-04  1.5234982e-05  5.1297218e-04]
#  [ 1.4696012e-03 -1.3645410e-03  2.7690909e-04  1.3980737e-03]], shape=(4, 4), dtype=float32)

# %%
d_k = tf.cast(d_k, tf.float32)

scaled_omega = omega / tf.sqrt(d_k)

attention_weights = tf.nn.softmax(scaled_omega, axis=-1)

print("Attention Weights")
print(attention_weights)
# Out:
# Attention Weights
# tf.Tensor(
# [[0.25019836 0.24965216 0.24996376 0.25018564]
#  [0.24980591 0.2503376  0.2500395  0.249817  ]
#  [0.25006482 0.24989435 0.24997641 0.2500644 ]
#  [0.2501811  0.24968022 0.24997021 0.25016847]], shape=(4, 4), dtype=float32)

# %%
row_sums = tf.reduce_sum(attention_weights, axis=-1)

print("Sum of each row in attention_weights")
row_sums
# Out:
# Sum of each row in attention_weights
# <tf.Tensor: shape=(4,), dtype=float32, numpy=array([0.9999999, 1.       , 1.       , 1.       ], dtype=float32)>

# %%
context_vector = tf.matmul(attention_weights, values)

print("Context Vector shape", context_vector.shape)
print(context_vector)
# Out:
# Context Vector shape (4, 4)
# tf.Tensor(
# [[0.01349192 0.01110587 0.01013392 0.0112408 ]
#  [0.01343185 0.01106044 0.01008872 0.01119618]
#  [0.01347115 0.01108996 0.01011829 0.01122509]
#  [0.01348936 0.01110398 0.01013199 0.01123896]], shape=(4, 4), dtype=float32)

# %%
class SelfAttention(tf.keras.layers.Layer):
    def __init__(self, d_in, d_out_kq, d_out_v):
        super().__init__()
        self.d_out_kq = d_out_kq

        self.W_query = tf.Variable(
            tf.random.uniform((d_in, d_out_kq)), trainable=True
        )
        self.W_key = tf.Variable(
            tf.random.uniform((d_in, d_out_kq)), trainable=True
        )
        self.W_value = tf.Variable(
            tf.random.uniform((d_in, d_out_v)), trainable=True
        )

    def call(self, x):
        keys = tf.matmul(x, self.W_key)      # [T, d_out_kq]
        queries = tf.matmul(x, self.W_query) # [T, d_out_kq]
        values = tf.matmul(x, self.W_value)  # [T, d_out_v]

        # Attention scores: QKᵀ
        attn_scores = tf.matmul(queries, keys, transpose_b=True)  # [T, T]

        # Softmax (scaled by sqrt(d_k))
        attn_weights = tf.nn.softmax(
            attn_scores / tf.math.sqrt(tf.cast(self.d_out_kq, tf.float32)), axis=-1
        )  # [T, T]

        # Weighted sum
        context_vec = tf.matmul(attn_weights, values)  # [T, d_out_v]
        return context_vec

# %%
tf.random.set_seed(123)

d_in, d_out_kq, d_out_v = 2, 2, 4

sa = SelfAttention(d_in, d_out_kq, d_out_v)

out = sa(embedded_sentence)

print(out.shape)  # (T, d_out_v)
print(out.numpy())
# Out:
# (4, 4)
# [[0.01349192 0.01110587 0.01013392 0.0112408 ]
#  [0.01343185 0.01106044 0.01008872 0.01119618]
#  [0.01347115 0.01108996 0.01011829 0.01122509]
#  [0.01348936 0.01110398 0.01013199 0.01123896]]

# %%
class MultiHeadAttentionWrapper(tf.keras.layers.Layer):
    def __init__(self, d_in, d_out_kq, d_out_v, num_heads):
        super().__init__()
        self.heads = [
            SelfAttention(d_in, d_out_kq, d_out_v)
            for _ in range(num_heads)
        ]

    def call(self, x):
        # รันทุก head แล้ว concat ตามแกนสุดท้าย
        head_outputs = [head(x) for head in self.heads]   # list of [T, d_out_v]
        return tf.concat(head_outputs, axis=-1)           # [T, num_heads * d_out_v]

# %%
tf.random.set_seed(123)

d_in, d_out_kq, d_out_v = 2, 2, 1

sa = SelfAttention(d_in, d_out_kq, d_out_v)

# ถ้า embedded_sentence.shape = [T, d_in] เช่น [6, 3]
out = sa(embedded_sentence)

print(out.shape)   # (T, d_out_v) -> (6, 1)
print(out.numpy())
# Out:
# (4, 1)
# [[0.01121058]
#  [0.01116249]
#  [0.01119386]
#  [0.01120855]]

# %%
tf.random.set_seed(123)

block_size = embedded_sentence.shape[0]   # [T, d_in] → T = sequence length

mha = MultiHeadAttentionWrapper(
    d_in, d_out_kq, d_out_v, num_heads=3
)

# run MHA
context_vecs = mha(embedded_sentence)   # [T, num_heads * d_out_v]

print(context_vecs)
print("context_vecs.shape:", context_vecs.shape)
# Out:
# tf.Tensor(
# [[0.01121058 0.01295754 0.01714121]
#  [0.01116249 0.01287463 0.01704159]
#  [0.01119386 0.01293763 0.01713562]
#  [0.01120855 0.01295196 0.01713023]], shape=(4, 3), dtype=float32)
# context_vecs.shape: (4, 3)
